# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

# %%
df_excel = pd.read_excel("dataset/jml_produksi_sampah.xlsx", sheet_name="data")
df_excel['total_produksi_tahunan'] = df_excel.apply(lambda baris:baris['jumlah_produksi_sampah']*365, axis=1)
print("Data dari df_excel (Belum dikelompokkan)")
df_excel
# Out:
# Data dari df_excel (Belum dikelompokkan)
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun  \
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
df_tahunan = df_excel.groupby(['nama_kabupaten_kota', 'tahun'])['total_produksi_tahunan'].sum().unstack()
print("Data dari df_tahunan (Total produksi di kategorikan berdasarkan Kabupaten/Kota dan Tahun Produksi)")
df_tahunan
# Out:
# Data dari df_tahunan (Total produksi di kategorikan berdasarkan Kabupaten/Kota dan Tahun Produksi)
# tahun                         2015       2016       2017        2018  \
# nama_kabupaten_kota
# KABUPATEN BANDUNG        692018.10  692018.10  692018.10   754841.90
# KABUPATEN BANDUNG BARAT  224869.20  224869.20  224869.20   242192.10
# KABUPATEN BEKASI         448439.00  448439.00  448439.00   584259.15
# KABUPATEN BOGOR          551569.75  551569.75  551569.75   626632.00
# KABUPATEN CIAMIS          95232.15   95232.15   95232.15    95998.65
# KABUPATEN CIANJUR        358214.65  358214.65  358214.65   352294.35
# KABUPATEN CIREBON        169998.75  169998.75  169998.75   170181.25
# KABUPATEN GARUT          169630.10  169630.10  169630.10   172969.85
# KABUPATEN INDRAMAYU      223810.70  223810.70  223810.70   220135.15
# KABUPATEN KARAWANG       317498.90  317498.90  317498.90   327350.25
# KABUPATEN KUNINGAN        91870.50   91870.50   91870.50    90709.80
# ...

# %%
print("Soal 1")
df_tahunan.plot(kind='bar', figsize=(18, 6), color=['skyblue', 'salmon', 'green', 'orange', 'purple', 'red', 'grey'])
plt.ylabel('Jumlah Produksi (Ton)')
plt.xlabel('Nama Kota/Kabupaten')
plt.title('Jumlah Produksi Tahunan')
plt.gca().yaxis.set_major_formatter(tck.StrMethodFormatter('{x:,.0f}'))
plt.tight_layout()
plt.show()
# Out:
# Soal 1
